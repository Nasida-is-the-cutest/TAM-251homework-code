# %%
import numpy as np
from numpy import pi

# %%
#HW1.1
a=0.2
b=1.2
c=0.3
f1=2
f2=9
f3=9
f4=2

s1=pi*(a/2)**2
s2=pi*(b/2)**2
s3=pi*(c/2)**2
a1=f1/s1
a2=(f1-f2)/s2
a3=f4/s3
print("a1=",a1)
print("a2=",a2)
print("a3=",a3)
# Out:
# a1= 63.66197723675813
# a2= -6.189358898018152
# a3= 28.29421210522584

# %%
#HW1.2
f1=3
f2=9
f3=5
f4=8
f5=18
#F1 F3 F5 连接在墙上，不作用在bolt上
f=max(f2/2,f4/2)
print("f=",f)
# Out:
# f= 4.5

# %%
#HW1.3
from scipy import integrate
w=7
def f(x):
    return 15*x**0.5*w
def m(x):
    return 15*x**0.5*w*x
p=integrate.quad(f,0,4)[0]
m=integrate.quad(m,0,4)[0]
d=m/p
print("p=",p)
print("d=",d)
# Out:
# p= 560.0
# d= 2.3999999999833768

# %%
#HW1.4
d=0.026
f=18000 #N
t=0.016 #m
sigma=f/(d*t)/1000000  #此处的正应力为挤压正应力，挤压面积为螺栓直径与板厚的乘积
print("sigma=",sigma)
tao=f/(d/2)**2/pi/1000000
print("tao=",tao)
# Out:
# sigma= 43.269230769230774
# tao= 33.9028281142499

# %%
#HW1.5
sigma_fail=50 #ksi
fs=1.5
thick=0.5
a=45
b=22
sigma_allow=sigma_fail/fs
h1=(a)/sigma_allow/thick
h2=(a+2*b)/sigma_allow/thick
print("h1=",h1)
print("h2=",h2)
# Out:
# h1= 2.6999999999999997
# h2= 5.34

# %%
#HW1.6
a=0.006 #m
b=0.017
c=0.002
l=0.008
f=20*1000 #N
sigma=f/(c*b)/1000000 #只有c*b部分承受正应力
print("sigma=",sigma)
tao=f/(l*b)/1000000 
print("tao=",tao)
# Out:
# sigma= 588.235294117647
# tao= 147.05882352941174

# %%
#HW1.7
tau_fail=390E6 #Pa
fs=2.5
tau_allow=tau_fail/fs
f=40000 #N
v=f/2
D=(4*v/pi/tau_allow)**0.5*1000 
print("D=",D)
# Out:
# D= 12.776378167094562

# %%
#HW1.8
m=3.2
ce=35
be=35
ab=230
angle=np.radians(75)
fbd=m*9.81*(ce+be+ab)/(ce+be)/np.sin(angle)
n=-fbd*np.cos(angle)
print("n",n)
v=m*9.81-fbd*np.sin(angle)
print("v",v)
M=-(m*9.81*(be+ab)-fbd*be*np.sin(angle))/1000
print("M",M)
# Out:
# n -36.04911878056202
# v -103.14514285714287
# M -3.610080000000001

# %%
#HW1.9
fs=5
f_fail=870 #N
f_allow=f_fail/fs
print("f_allow=",f_allow)
# Out:
# f_allow= 174.0

# %%
#HW1.10
angle=np.radians(90)
theta=2
l=521
angle_prime=np.radians(90+theta)
ab=l/2**0.5
ad=l/2**0.5
bd=(ab**2+ad**2-2*ab*ad*np.cos(angle_prime))**0.5
k=(bd-l)/l
print("k=",k)
# Out:
# k= 0.017300101593674566
